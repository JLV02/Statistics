# %% [markdown]
# # List and Tuples <hr style = "border:2.5px solid rgba(21, 6, 225, 1)"></hr>

# %% [markdown]
# <b> Jeremy Lloyd L. Vallejera </b>
# <br> Computer Engineering Technology

# %% [markdown]
# # CREATING A LIST

# %%
numbers = [1,2,3,4,5]
numbers
# Out:
# [1, 2, 3, 4, 5]

# %%
type(numbers)
# Out:
# list

# %%
fruit = ['apple', 'banana', 'grape']
fruit
# Out:
# ['apple', 'banana', 'grape']

# %%
mixed_list = [10,'JL',2.4,True ]
mixed_list
# Out:
# [10, 'JL', 2.4, True]

# %% [markdown]
# # INDEXING

# %%
numbers = [1,2,3,4,5]
numbers[0]
# Out:
# 1

# %% [markdown]
# # MODIFYING ELEMENTS

# %%
fruit[0] = "JL"
fruit
# Out:
# ['JL', 'banana', 'grape']

# %%
fruit[0] = "Apple"
fruit
# Out:
# ['Apple', 'banana', 'grape']

# %% [markdown]
# # ADDING ELEMENTS

# %%
fruit.append("orange")
fruit
# Out:
# ['Apple', 'banana', 'grape', 'orange']

# %%
fruit.insert(1,"JL")
fruit
# Out:
# ['Apple', 'JL', 'banana', 'grape', 'orange']

# %% [markdown]
# # REMOVING ELEMENTS

# %%
fruit.remove("JL")
fruit
# Out:
# ['Apple', 'banana', 'grape', 'orange']

# %%
"Apple" in fruit
# Out:
# True

# %%
"JL" in fruit
# Out:
# False

# %%
fruit.pop(0)
fruit
# Out:
# ['banana', 'grape', 'orange']

# %% [markdown]
# # SORT() AND SORTED()

# %%
number=[4,3,5,2,1]
number
# Out:
# [4, 3, 5, 2, 1]

# %%
number.sort()
number
# Out:
# [1, 2, 3, 4, 5]

# %%
sorted(numbers)
numbers
# Out:
# [1, 2, 3, 4, 5]

# %% [markdown]
# # SLICING

# %%
chars = ['J','E','R','E','M','Y']
chars
# Out:
# ['J', 'E', 'R', 'E', 'M', 'Y']

# %%
len(chars)
chars
# Out:
# ['J', 'E', 'R', 'E', 'M', 'Y']

# %%
chars[0:3]
# Out:
# ['J', 'E', 'R']

# %%
sub = chars[0:6:2]
sub
# Out:
# ['J', 'R', 'M']

# %% [markdown]
# # TUPLE

# %%
my_tuple = (1,2,3,4,5,)
my_tuple
# Out:
# (1, 2, 3, 4, 5)

# %%
type(my_tuple)
# Out:
# tuple

# %%
len(my_tuple)
# Out:
# 5

# %%
my_tuple[1:3]
# Out:
# (2, 3)
